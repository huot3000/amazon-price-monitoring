# %%
import requests
from requests_html import HTML
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
options = Options()
options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
url = 'https://www.amazon.ca/dp/B07MWV1JD7/ref=s9_acsd_otopr_hd_bw_b2f3hb1_c2_x_1_i?pf_rd_m=A1IM4EOPHS76S7&pf_rd_s=merchandised-search-11&pf_rd_r=AP9WVTJV56YHHEXS70NN&pf_rd_t=101&pf_rd_p=4f54e965-bbab-5e15-a3d6-9164b7925043&pf_rd_i=2438978011'
title_lookup = '#productTitle'
price_lookup = '#priceblock_ourprice'

# %%
# requests is not working
# r = requests.get(url)
# html_str = r.text

# %%
# print(html_str)
driver.get(url)
body_el = driver.find_element_by_css_selector('body')
html_str = body_el.get_attribute('innerHTML')
print(html_str)
# Out:
# <div id="ap_container"></div><iframe frameborder="0" tabindex="-1" src="javascript:void(false)" style="display:none;position:absolute;z-index:0;filter:Alpha(Opacity='0');opacity:0;"></iframe><iframe frameborder="0" tabindex="-1" src="javascript:void(false)" style="display:none;position:absolute;z-index:0;filter:Alpha(Opacity='0');opacity:0;"></iframe><iframe frameborder="0" tabindex="-1" src="javascript:void(false)" style="display:none;position:absolute;z-index:0;filter:Alpha(Opacity='0');opacity:0;"></iframe><div id="a-page"><script type="a-state" data-a-state="{&quot;key&quot;:&quot;a-wlab-states&quot;}">{"AUI_LINK_REL_NOREFERRER_NOOPENER_274172":"C","AUI_TNR_V2_180836":"C","AUI_UX_145937":"C","AUI_DROPDOWN_274033":"C","AUI_PRELOAD_261698":"C","AUI_72554":"C","AUI_CONTROL_GROUP_273125":"C","AUI_PCI_RISK_BANNER_210084":"C","AUI_PERF_130093":"C"}</script><script>typeof uex === 'function' && uex('ld', 'portal-bb', {wb: 1})</script>    <img height="1" width="1" style="display:none;visi
# ...

# %%
html_obj = HTML(html=html_str)

# %%
product_title = html_obj.find(title_lookup, first=True).text
print(product_title)
# Out:
# Sunny Health & Fitness Fully Assembled Magnetic Under Desk/Stand Up Elliptical Machine

# %%
product_price = html_obj.find(price_lookup, first=True).text
print(product_price)
# Out:
# CDN$ 185.99
